# %%
import numpy as np
import matplotlib.pyplot as plt
file_path = "/home/ome123/CLionProjects/task4/cmake-build-debug/result_u.txt"  # Замените на путь к вашему файлу
with open(file_path, 'r') as file:
    x_data = file.readline().strip().split()
    u_data = file.readline().strip().split()
    v_data = file.readline().strip().split()

file_path1 = "/home/ome123/CLionProjects/task4/cmake-build-debug/result_v.txt"  # Замените на путь к вашему файлу
with open(file_path1, 'r') as file:
    x1_data = file.readline().strip().split()
    v_data = file.readline().strip().split()
# Преобразование данных в массивы numpy
x = np.array(x_data, dtype=float)
y = np.array(u_data, dtype=float)
v = np.array(v_data, dtype=float)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))  # 3 строки, 1 столбец

# Первый график
ax1.plot(x, y, color='blue', label='u(x)')
ax1.set_title('Метод несимметричной разностной производной')
ax1.legend()
ax1.grid(True)

# Второй график
ax2.plot(x, v, color='red', label='v(x)')
ax2.set_title('Метод фиктивного узла')
ax2.legend()
ax2.grid(True)
